# %%
import sympy as sp
import numpy as np

# %%
x = sp.symbols("x")
eq = sp.exp(x*(-x-3.887344))
eq_simplified = sp.simplify(eq)
sp.init_printing()
display(eq_simplified)
# Out:
#  -x⋅(x + 3.887344)
# ℯ
